# %%
import csv
import numpy as np 
import pandas as pd

# %%
data = pd.read_csv("songs_dataset.csv")
data.head()
# Out:
#         Singer               Album                            Song  \
# 0  $UICIDEBOY$  7th or St. Tammany                  40 Oz. & Sober
# 1  $UICIDEBOY$  7th or St. Tammany              7th or St. Tammany
# 2  $UICIDEBOY$  7th or St. Tammany                  Dead Batteries
# 3  $UICIDEBOY$  7th or St. Tammany           Drugs/Hoes/Money/Etc.
# 4  $UICIDEBOY$  7th or St. Tammany  I’ll Pay for It (If I Want It)
#
#          Date Featuring                                 Genre  \
# 0  2015-04-02        []  ['Alternative/Indie', 'Hip-Hop/Rap']
# 1  2015-04-02        []                       ['Hip-Hop/Rap']
# 2  2015-03-19        []                       ['Hip-Hop/Rap']
# 3  2015-04-02        []                       ['Hip-Hop/Rap']
# 4  2015-04-02        []                       ['Hip-Hop/Rap']
#
#                                               Lyrics                    Tags  \
# 0  \n\n[Hook: Gangsta Pat]\nKiller, killer, kille...  ['Alternative', 'Rap']
# ...

# %%
data=data.drop(["Date", "Song", "Album", "Singer", "Writers", "Producers", "Featuring"], axis=1)
data.head()
print(data.shape)
# Out:
# (253678, 3)

# %%
data.head(5)
# Out:
#                                   Genre  \
# 0  ['Alternative/Indie', 'Hip-Hop/Rap']
# 1                       ['Hip-Hop/Rap']
# 2                       ['Hip-Hop/Rap']
# 3                       ['Hip-Hop/Rap']
# 4                       ['Hip-Hop/Rap']
#
#                                               Lyrics                    Tags
# 0  \n\n[Hook: Gangsta Pat]\nKiller, killer, kille...  ['Alternative', 'Rap']
# 1  \n\nUh\n*59, yah!\nUhhhh, [?]\n*59 motherfucke...                 ['Rap']
# 2  \n\n[Produced by Budd Dwyer]\n\n[Intro: Frayse...                 ['Rap']
# 3  \n\n[Verse 1: YUNG $NOW]\nCounting sheep until...                 ['Rap']
# 4  \n\n[Verse 1: RUBY DA CHERRY]\nFucking Ruby go...                 ['Rap']

# %%
print(data['Genre'].unique())
print(len(data['Tags'].unique()))
# Out:
# ["['Alternative/Indie', 'Hip-Hop/Rap']" "['Hip-Hop/Rap']" "['Rock']"
#  "['Pop']" "['Rock', 'Alternative/Indie']" "['Rock', 'Pop']"
#  "['Pop', 'Hip-Hop/Rap']" "['R&B/Soul', 'Hip-Hop/Rap']"
#  "['Rock', 'Hip-Hop/Rap']" "['R&B/Soul', 'Blues/Jazz', 'Hip-Hop/Rap']"
#  "['Metal', 'Rock', 'Alternative/Indie', 'Hip-Hop/Rap']"
#  "['Pop', 'R&B/Soul', 'Blues/Jazz', 'Hip-Hop/Rap']" "['R&B/Soul']"
#  "['Pop', 'R&B/Soul', 'Hip-Hop/Rap']"
#  "['Rock', 'Alternative/Indie', 'Pop', 'Hip-Hop/Rap']"
#  "['Rock', 'Punk', 'Hip-Hop/Rap']"
#  "['Rock', 'Alternative/Indie', 'Hip-Hop/Rap']"
#  "['Metal', 'Rock', 'Alternative/Indie']" "['Rock', 'Pop', 'Hip-Hop/Rap']"
#  "['Rock', 'Punk', 'Pop']" "['Rock', 'Alternative/Indie', 'Pop']"
#  "['Rock', 'Pop', 'R&B/Soul', 'Hip-Hop/Rap']"
#  "['Folk', 'Rock', 'Hip-Hop/Rap']" "['Folk', 'Rock']"
#  "['Rock', 'R&B/Soul', 'Hip-Hop/Rap']"
#  "['Rock', 'Alternative/Indie', 'Pop', 'R&B/Soul', 'Hip-Hop/Rap']"
#  "['Folk', 'Rock', 'R&B/Soul']"
# ...

# %%
# remove "Verse :", "Hook: ", "Chorus :", remove "\n".

# %% [markdown]
# ## MetroLyrics

# %%
metro = pd.read_csv("metrolyrics.csv")
print(metro.head())
# Out:
#    index             song  year           artist genre  \
# 0      0        ego-remix  2009  beyonce-knowles   Pop
# 1      1     then-tell-me  2009  beyonce-knowles   Pop
# 2      2          honesty  2009  beyonce-knowles   Pop
# 3      3  you-are-my-rock  2009  beyonce-knowles   Pop
# 4      4    black-culture  2009  beyonce-knowles   Pop
#
#                                               lyrics
# 0  Oh baby, how you doing?\nYou know I'm gonna cu...
# 1  playin' everything so easy,\nit's like you see...
# 2  If you search\nFor tenderness\nIt isn't hard t...
# 3  Oh oh oh I, oh oh oh I\n[Verse 1:]\nIf I wrote...
# 4  Party the people, the people the party it's po...

# %%
print(metro['genre'].unique())
# Out:
# ['Pop' 'Hip-Hop' 'Not Available' 'Other' 'Rock' 'Metal' 'Country' 'Jazz'
#  'Electronic' 'Folk' 'R&B' 'Indie']
